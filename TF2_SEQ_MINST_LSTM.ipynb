# %%
'''
RNN for MNIST digits classification
97.7% test accuracy in 20epochs
75K adjustable parameters
input -> 256 -> 10

https://github.com/PacktPublishing/Advanced-Deep-Learning-with-Keras
'''

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, SimpleRNN, LSTM, Input
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.datasets import mnist

# %%
# !python --version
# !pip list | grep tensorflow
# Out:
# Python 3.6.9
# tensorflow                    2.4.0
# tensorflow-addons             0.8.3
# tensorflow-datasets           4.0.1
# tensorflow-estimator          2.4.0
# tensorflow-gcs-config         2.4.0
# tensorflow-hub                0.10.0
# tensorflow-metadata           0.26.0
# tensorflow-privacy            0.2.2
# tensorflow-probability        0.11.0

# %% [markdown]
# ## Clean Data

# %%
# load mnist dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# compute the number of labels
num_labels = len(np.unique(y_train))

# convert to one-hot vector
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# resize and normalize
#image_size = x_train.shape[1]
#print(x_train.shape)

x_train = np.reshape(x_train,[x_train.shape[0], -1, 1])
x_test = np.reshape(x_test,[x_test.shape[0], -1, 1])

x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

print("x_train", x_train.shape)
print("y_train", y_train.shape)

print("x_test", x_test.shape)
print("y_test", y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train (60000, 784, 1)
# y_train (60000, 10)
# x_test (10000, 784, 1)
# y_test (10000, 10)

# %% [markdown]
# ## Setup Model

# %%
# network parameters
input_shape = (x_train.shape[1:])
batch_size = 128
units = 100
dropout = 0.00

# model is RNN with 256 units, input is 28-dim vector 28 timesteps
model = Sequential()
model.add(Input(input_shape, name="input"))
model.add(LSTM(units=units,
                    dropout=dropout, name="ltsm" ))
                    #input_shape=input_shape))
model.add(Dense(num_labels, name="dense"))
model.add(Activation('softmax', name="activate"))
model.summary()
print("units", units)
print("input_shape", input_shape)
print("num_labels", num_labels)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# ltsm (LSTM)                  (None, 100)               40800
# _________________________________________________________________
# dense (Dense)                (None, 10)                1010
# _________________________________________________________________
# activate (Activation)        (None, 10)                0
# =================================================================
# Total params: 41,810
# Trainable params: 41,810
# Non-trainable params: 0
# _________________________________________________________________
# units 100
# input_shape (784, 1)
# num_labels 10

# %% [markdown]
# ## Model compile and fit (train)

# %%
# enable this if pydot can be installed
# pip install pydot
#plot_model(model, to_file='rnn-mnist.png', show_shapes=True)

# loss function for one-hot vector
# use of sgd optimizer
# accuracy is good metric for classification tasks

from keras.optimizers import RMSprop

learning_rate = 1e-3
rmsprop = RMSprop(lr=learning_rate)

model.compile(loss='categorical_crossentropy',
              optimizer= rmsprop,
              metrics=['accuracy'])

#model.compile(loss='categorical_crossentropy',
#              optimizer='sgd',
#              metrics=['accuracy'])
# train the network

model.fit(x_train, y_train, 
          epochs=200, 
          batch_size=batch_size,
          validation_data=(x_test, y_test))
# Out:
# Epoch 1/200
# 469/469 [==============================] - 24s 40ms/step - loss: 2.2706 - accuracy: 0.1542 - val_loss: 3.0370 - val_accuracy: 0.1135
# Epoch 2/200
# 469/469 [==============================] - 18s 39ms/step - loss: 2.1311 - accuracy: 0.2264 - val_loss: 1.8454 - val_accuracy: 0.2880
# Epoch 3/200
# 469/469 [==============================] - 18s 39ms/step - loss: 1.8051 - accuracy: 0.3086 - val_loss: 3.1324 - val_accuracy: 0.0983
# Epoch 4/200
# 469/469 [==============================] - 18s 39ms/step - loss: 1.9838 - accuracy: 0.2799 - val_loss: 1.7885 - val_accuracy: 0.3155
# Epoch 5/200
# 469/469 [==============================] - 18s 39ms/step - loss: 2.1522 - accuracy: 0.1909 - val_loss: 2.3056 - val_accuracy: 0.1135
200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.9920 - accuracy: 0.6521 - val_loss: 1.3049 - val_accuracy: 0.5165
# Epoch 27/200
# 469/469 [==============================] - 19s 41ms/step - loss: 1.0490 - accuracy: 0.6328 - val_loss: 0.8822 - val_accuracy: 0.6814
# Epoch 28/200
# 469/469 [==============================] - 20s 42ms/step - loss: 0.8876 - accuracy: 0.6758 - val_loss: 0.9080 - val_accuracy: 0.6745
# Epoch 29/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.7547 - accuracy: 0.7255 - val_loss: 0.6165 - val_accuracy: 0.7721
# Epoch 30/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.7327 - accuracy: 0.7344 - val_loss: 0.6308 - val_accuracy: 0.7630
# Epoch 31/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.6003 - accuracy: 0.7801 - val_loss: 0.5879 - val_accuracy: 0.7831
# Epoch 32/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.7063 - accuracy: 0.7448 - val_loss: 0.5057 - val_accuracy: 0.8083
# Epoch 33/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.5240 - accuracy: 0.8072 - val_loss: 0.5389 - val_accuracy: 0.7995
# Epoch 34/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.4724 - accuracy: 0.8247 - val_loss: 0.4293 - val_accuracy: 0.8283
# Epoch 35/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.4277 - accuracy: 0.8414 - val_loss: 0.4013 - val_accuracy: 0.8418
# Epoch 36/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.3947 - accuracy: 0.8520 - val_loss: 0.3529 - val_accuracy: 0.8596
# Epoch 37/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.3924 - accuracy: 0.8536 - val_loss: 0.3613 - val_accuracy: 0.8573
# Epoch 38/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.3479 - accuracy: 0.8644 - val_loss: 0.4262 - val_accuracy: 0.8343
# Epoch 39/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.3304 - accuracy: 0.8733 - val_loss: 0.3085 - val_accuracy: 0.8752
# Epoch 40/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.3150 - accuracy: 0.8809 - val_loss: 0.3049 - val_accuracy: 0.8911
# Epoch 41/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.2930 - accuracy: 0.8995 - val_loss: 0.2587 - val_accuracy: 0.9220
# Epoch 42/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.2368 - accuracy: 0.9262 - val_loss: 0.1805 - val_accuracy: 0.9436
# Epoch 43/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.2079 - accuracy: 0.9348 - val_loss: 0.1927 - val_accuracy: 0.9395
# Epoch 44/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.1972 - accuracy: 0.9391 - val_loss: 0.1598 - val_accuracy: 0.9542
# Epoch 45/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.1783 - accuracy: 0.9465 - val_loss: 0.1707 - val_accuracy: 0.9463
# Epoch 46/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.1613 - accuracy: 0.9505 - val_loss: 0.1805 - val_accuracy: 0.9439
# Epoch 47/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.1501 - accuracy: 0.9544 - val_loss: 0.1137 - val_accuracy: 0.9632
# Epoch 48/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.1431 - accuracy: 0.9562 - val_loss: 0.1123 - val_accuracy: 0.9656
# Epoch 49/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.1332 - accuracy: 0.9591 - val_loss: 0.1410 - val_accuracy: 0.9564
# Epoch 50/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.1270 - accuracy: 0.9613 - val_loss: 0.1100 - val_accuracy: 0.9662
# Epoch 51/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.1168 - accuracy: 0.9646 - val_loss: 0.0970 - val_accuracy: 0.9706
# Epoch 52/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.1116 - accuracy: 0.9659 - val_loss: 0.0906 - val_accuracy: 0.9740
# Epoch 53/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.1058 - accuracy: 0.9684 - val_loss: 0.1895 - val_accuracy: 0.9391
# Epoch 54/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0987 - accuracy: 0.9702 - val_loss: 0.1509 - val_accuracy: 0.9541
# Epoch 55/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0920 - accuracy: 0.9719 - val_loss: 0.1013 - val_accuracy: 0.9705
# Epoch 56/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0880 - accuracy: 0.9738 - val_loss: 0.0774 - val_accuracy: 0.9765
# Epoch 57/200
# 469/469 [==============================] - 20s 42ms/step - loss: 0.0886 - accuracy: 0.9737 - val_loss: 0.0876 - val_accuracy: 0.9732
# Epoch 58/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0826 - accuracy: 0.9754 - val_loss: 0.0853 - val_accuracy: 0.9741
# Epoch 59/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0760 - accuracy: 0.9774 - val_loss: 0.0823 - val_accuracy: 0.9735
# Epoch 60/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0719 - accuracy: 0.9779 - val_loss: 0.0656 - val_accuracy: 0.9792
# Epoch 61/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0678 - accuracy: 0.9793 - val_loss: 0.0707 - val_accuracy: 0.9784
# Epoch 62/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0663 - accuracy: 0.9794 - val_loss: 0.0802 - val_accuracy: 0.9754
# Epoch 63/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0619 - accuracy: 0.9811 - val_loss: 0.0590 - val_accuracy: 0.9826
# Epoch 64/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0594 - accuracy: 0.9816 - val_loss: 0.0592 - val_accuracy: 0.9816
# Epoch 65/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0573 - accuracy: 0.9827 - val_loss: 0.0760 - val_accuracy: 0.9776
# Epoch 66/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0565 - accuracy: 0.9829 - val_loss: 0.0622 - val_accuracy: 0.9813
# Epoch 67/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0519 - accuracy: 0.9835 - val_loss: 0.0654 - val_accuracy: 0.9803
# Epoch 68/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0571 - accuracy: 0.9826 - val_loss: 0.0669 - val_accuracy: 0.9795
# Epoch 69/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0480 - accuracy: 0.9844 - val_loss: 0.0634 - val_accuracy: 0.9813
# Epoch 70/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0486 - accuracy: 0.9855 - val_loss: 0.0997 - val_accuracy: 0.9715
# Epoch 71/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0487 - accuracy: 0.9846 - val_loss: 0.0549 - val_accuracy: 0.9826
# Epoch 72/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0415 - accuracy: 0.9868 - val_loss: 0.0496 - val_accuracy: 0.9854
# Epoch 73/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0451 - accuracy: 0.9857 - val_loss: 0.0745 - val_accuracy: 0.9799
# Epoch 74/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0457 - accuracy: 0.9864 - val_loss: 0.0594 - val_accuracy: 0.9834
# Epoch 75/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0414 - accuracy: 0.9877 - val_loss: 0.0643 - val_accuracy: 0.9804
# Epoch 76/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0400 - accuracy: 0.9875 - val_loss: 0.0519 - val_accuracy: 0.9856
# Epoch 77/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0404 - accuracy: 0.9877 - val_loss: 0.0616 - val_accuracy: 0.9837
# Epoch 78/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0389 - accuracy: 0.9879 - val_loss: 0.0534 - val_accuracy: 0.9846
# Epoch 79/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0357 - accuracy: 0.9880 - val_loss: 0.0534 - val_accuracy: 0.9838
# Epoch 80/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0341 - accuracy: 0.9894 - val_loss: 0.0523 - val_accuracy: 0.9853
# Epoch 81/200
# 469/469 [==============================] - 19s 39ms/step - loss: 0.0350 - accuracy: 0.9891 - val_loss: 0.0843 - val_accuracy: 0.9761
# Epoch 82/200
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0358 - accuracy: 0.9884 - val_loss: 0.0463 - val_accuracy: 0.9861
# Epoch 83/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0349 - accuracy: 0.9890 - val_loss: 0.0522 - val_accuracy: 0.9833
# Epoch 84/200
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0317 - accuracy: 0.9904 - val_loss: 0.0488 - val_accuracy: 0.9850
# Epoch 85/200
# 469/469 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 0.9896

# %% [markdown]
# ## Model pred

# %%
_, acc = model.evaluate(x_test,
                        y_test,
                        batch_size=batch_size,
                        verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * acc))
